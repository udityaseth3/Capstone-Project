# %%
import cv2
import numpy as np

# camera
cap = cv2.VideoCapture("cam.mp4")

while True:
    ret,frame1= cap.read()

    cv2.imshow('Video Original',frame1)

    if cv2.waitKey(1) == 13:
        break
cv2.destroyAllWindows()
cap.release()

# %%
##BACKGROUND CHANGE
import cv2
import numpy as np

# camera
cap = cv2.VideoCapture("cam.mp4")

#Initialialize Substructor
algo = cv2.bgsegm.createBackgroundSubtractorMOG()

while True:
    ret,frame1= cap.read()
    grey = cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(grey,(3,3),5)
   # applying on each frame
    img_sub = algo.apply(blur)
    dilat = cv2.dilate(img_sub,np.ones(5,5)))
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
    dilatada = cv2.morphologyEx(dilat., cv2.MORPH_CLOSE,kernel)
    dilatada = cv2.morphologyEx(dilatada., cv2.MORPH_CLOSE,kernel)
    counter = cv2.FindContours(dilatada,cv2.RETER_TREE, cv2.CHAIN_APPROX_SIMPLE)
    

    cv2.imshow('Detector',dilatada)

    if cv2.waitKey(1) == 13:
        break
cv2.destroyAllWindows()
cap.release()

# %%
##LINE CODE
import cv2
import numpy as np

# camera
cap = cv2.VideoCapture("cam.mp4")

count_line_position= 550
#Initialialize Substructor
algo = cv2.bgsegm.createBackgroundSubtractorMOG()

while True:
    ret,frame1= cap.read()
    grey = cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(grey,(3,3),5)
   # applying on each frame
    img_sub = algo.apply(blur)
    dilat = cv2.dilate(img_sub,np.ones(5,5)))
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
    dilatada = cv2.morphologyEx(dilat., cv2.MORPH_CLOSE,kernel)
    dilatada = cv2.morphologyEx(dilatada., cv2.MORPH_CLOSE,kernel)
    counter = cv2.FindContours(dilatada,cv2.RETER_TREE, cv2.CHAIN_APPROX_SIMPLE)
cv2.line(frame1,(25,count_line_position),(1200,count_line_position),(255,127,0)
    

    cv2.imshow('Detector',dilatada)

    if cv2.waitKey(1) == 13:
        break
cv2.destroyAllWindows()
cap.release()

# %%
#COUNT CODE
import cv2
import numpy as np

# camera
cap = cv2.VideoCapture("cam.mp4")

min_width_reactangle=80 #min width rectangle
min_hieght_react=80   #min width reactangle

count_line_position= 550
#Initialialize Substructor
algo = cv2.bgsegm.createBackgroundSubtractorMOG()

while True:
    ret,frame1= cap.read()
    grey = cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(grey,(3,3),5)
   # applying on each frame
    img_sub = algo.apply(blur)
    dilat = cv2.dilate(img_sub,np.ones(5,5)))
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
    dilatada = cv2.morphologyEx(dilat., cv2.MORPH_CLOSE,kernel)
    dilatada = cv2.morphologyEx(dilatada., cv2.MORPH_CLOSE,kernel)
    counterSahape,h= cv2.FindContours(dilatada,cv2.RETER_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cv2.line(frame1,(25,count_line_position),(1200,count_line_position),(255,127,0)

    for(i,c) in enumerate(counterShape):
        (x,y,w,h) = cv2.boundingRect(c)
        validate_counter = (w>= min_width_react) and (h>= min_height_reat)
         if not validate_ counter:
            continue
             cv2.rectangle(frame1,(x,y),(x+w,y+h),(0,255,0),2

    cv2.imshow('Detector',dilatada)

    if cv2.waitKey(1) == 13:
        break
cv2.destroyAllWindows()
cap.release()

# %%
# OBJECT DETECTION
import cv2
import numpy as np

# camera
cap = cv2.VideoCapture("cam.mp4")

min_width_reactangle=80 #min width rectangle
min_hieght_react=80   #min width reactangle

count_line_position= 550
#Initialialize Substructor
algo = cv2.bgsegm.createBackgroundSubtractorMOG()

def center_handel(x,y,w,h)
     x1=int(w/2)
     y1=int(h/2)
     cx= x+x1
     cy= y+y1
    return cx,cy
detect = []

while True:
    ret,frame1= cap.read()
    grey = cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(grey,(3,3),5)
   # applying on each frame
    img_sub = algo.apply(blur)
    dilat = cv2.dilate(img_sub,np.ones(5,5)))
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
    dilatada = cv2.morphologyEx(dilat., cv2.MORPH_CLOSE,kernel)
    dilatada = cv2.morphologyEx(dilatada., cv2.MORPH_CLOSE,kernel)
    counterSahape,h= cv2.FindContours(dilatada,cv2.RETER_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cv2.line(frame1,(25,count_line_position),(1200,count_line_position),(255,127,0)

    for(i,c) in enumerate(counterShape):
        (x,y,w,h) = cv2.boundingRect(c)
        validate_counter = (w>= min_width_react) and (h>= min_height_reat)
         if not validate_ counter:
            continue
             cv2.rectangle(frame1,(x,y),(x+w,y+h),(0,255,0),2

             center= center_handle(x,y,w,h)
             detect.append(center)
             cv2.circle(frame1,center,4, (0,0,255),-1)

    cv2.imshow('Detector',dilatada)

    if cv2.waitKey(1) == 13:
        break
cv2.destroyAllWindows()
cap.release()
